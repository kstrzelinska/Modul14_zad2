# %%
import pandas as pd
source_data = pd.read_csv('penguins.csv')
source_data
# Out:
#      CulmenLength  CulmenDepth  FlipperLength  BodyMass  Species
# 0            39.1         18.7          181.0    3750.0        0
# 1            39.5         17.4          186.0    3800.0        0
# 2            40.3         18.0          195.0    3250.0        0
# 3             NaN          NaN            NaN       NaN        0
# 4            36.7         19.3          193.0    3450.0        0
# ..            ...          ...            ...       ...      ...
# 339          55.8         19.8          207.0    4000.0        2
# 340          43.5         18.1          202.0    3400.0        2
# 341          49.6         18.2          193.0    3775.0        2
# 342          50.8         19.0          210.0    4100.0        2
# 343          50.2         18.7          198.0    3775.0        2
#
# [344 rows x 5 columns]

# %%
data = source_data.dropna()
data
# Out:
#      CulmenLength  CulmenDepth  FlipperLength  BodyMass  Species
# 0            39.1         18.7          181.0    3750.0        0
# 1            39.5         17.4          186.0    3800.0        0
# 2            40.3         18.0          195.0    3250.0        0
# 4            36.7         19.3          193.0    3450.0        0
# 5            39.3         20.6          190.0    3650.0        0
# ..            ...          ...            ...       ...      ...
# 339          55.8         19.8          207.0    4000.0        2
# 340          43.5         18.1          202.0    3400.0        2
# 341          49.6         18.2          193.0    3775.0        2
# 342          50.8         19.0          210.0    4100.0        2
# 343          50.2         18.7          198.0    3775.0        2
#
# [342 rows x 5 columns]

# %%
features = ['CulmenLength','CulmenDepth','FlipperLength','BodyMass']
target = 'Species'
X, y = data[features], data[target]
print('X:')
display(X)
print('\ny:')
display(y)
# Out:
# X:
#      CulmenLength  CulmenDepth  FlipperLength  BodyMass
# 0            39.1         18.7          181.0    3750.0
# 1            39.5         17.4          186.0    3800.0
# 2            40.3         18.0          195.0    3250.0
# 4            36.7         19.3          193.0    3450.0
# 5            39.3         20.6          190.0    3650.0
# ..            ...          ...            ...       ...
# 339          55.8         19.8          207.0    4000.0
# 340          43.5         18.1          202.0    3400.0
# 341          49.6         18.2          193.0    3775.0
# 342          50.8         19.0          210.0    4100.0
# 343          50.2         18.7          198.0    3775.0
#
# [342 rows x 4 columns]
# y:
# 0      0
# 1      0
# 2      0
# 4      0
# 5      0
#       ..
# 339    2
# 340    2
# 341    2
# 342    2
# 343    2
# Name: Species, Length: 342, dtype: int64

# %%
pd.Series(y).value_counts(normalize=True)
# Out:
# Species
# 0    0.441520
# 1    0.359649
# 2    0.198830
# Name: proportion, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 342 entries, 0 to 343
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CulmenLength   342 non-null    float64
#  1   CulmenDepth    342 non-null    float64
#  2   FlipperLength  342 non-null    float64
#  3   BodyMass       342 non-null    float64
#  4   Species        342 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 16.0 KB

# %%
X.describe()
# Out:
#        CulmenLength  CulmenDepth  FlipperLength     BodyMass
# count    342.000000   342.000000     342.000000   342.000000
# mean      43.921930    17.151170     200.915205  4201.754386
# std        5.459584     1.974793      14.061714   801.954536
# min       32.100000    13.100000     172.000000  2700.000000
# 25%       39.225000    15.600000     190.000000  3550.000000
# 50%       44.450000    17.300000     197.000000  4050.000000
# 75%       48.500000    18.700000     213.000000  4750.000000
# max       59.600000    21.500000     231.000000  6300.000000

# %%
import matplotlib.pyplot as plt
for col in features:
    print(f'Unique values: {len(data[col].unique())}')
    data.boxplot(column=col, by='Species', figsize=(6,5))
    plt.title(col)
    plt.show()
# Out:
# Unique values: 164
# Unique values: 80
# Unique values: 55
# Unique values: 94

# %%
import seaborn as sns
for col in features:
    plt.figure(figsize=(12, 2.5))
    sns.distplot(data.loc[data['Species']==0, col], kde=True, color='green', label='0')
    sns.distplot(data.loc[data['Species']==1, col], kde=True, color='red', label='1')
    sns.distplot(data.loc[data['Species']==2, col], kde=True, color='blue', label='2')
    plt.legend(loc='upper right')
    plt.show()
# Out:
# C:\Users\Kasia\AppData\Local\Temp\ipykernel_10856\1520261517.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.loc[data['Species']==0, col], kde=True, color='green', label='0')
# C:\Users\Kasia\AppData\Local\Temp\ipykernel_10856\1520261517.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
plt.figure(figsize=(8, 8))
ax = sns.heatmap(X.corr(),
                 xticklabels=X.corr().columns,
                 yticklabels=X.corr().columns,
                 cmap='RdYlGn',
                 center=0,
                 annot=True)

plt.title('Korelacja dla zmiennych numerycznych', fontsize=22)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
import pandas as pd
from scipy import stats

corr_dict = {}
for col in X.columns:
    corr_dict[col] = stats.pointbiserialr(X[col], y)[0]

# Wyświetlanie posortowanych wartości korelacji
pd.Series(corr_dict).sort_values(ascending=False)
# Out:
# CulmenLength     0.779857
# FlipperLength    0.357472
# BodyMass         0.209717
# CulmenDepth     -0.183090
# dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X[['FlipperLength', 'CulmenLength']], y, test_size=0.30, random_state=0, stratify=y)
print ('Treningowe obserwacje: %d\nTestowe obserwacje: %d' % (X_train.shape[0], X_test.shape[0]))
# Out:
# Treningowe obserwacje: 239
# Testowe obserwacje: 103

# %%
from numpy import where
from numpy import meshgrid
from numpy import arange
from numpy import hstack

def plot_classification_surface(X_plot, y_plot, trained_model):
    plt.figure(figsize=(12, 7))

    # określenie granic zbioru
    min1, max1 = X_plot[:, 0].min()-1, X_plot[:, 0].max()+1
    min2, max2 = X_plot[:, 1].min()-1, X_plot[:, 1].max()+1

    # skalowanie dla obu osi
    x1grid = arange(min1, max1, 0.1)
    x2grid = arange(min2, max2, 0.1)

    # utworzenie siatki
    xx, yy = meshgrid(x1grid, x2grid)

    # przetworzenie siatki w wektor
    r1, r2 = xx.flatten(), yy.flatten()
    r1, r2 = r1.reshape((len(r1), 1)), r2.reshape((len(r2), 1))

    # stworzenie zmiennych objaśniających dla modelu
    grid = hstack((r1,r2))

    # predykcja modelu zbioru
    yhat = trained_model.predict(grid)

    # przetworzenie predykcji na decyzji dla konkretnego punktu wykresu
    zz = yhat.reshape(xx.shape)

    # wizualizacja siatki z przyporządkowaną klasą
    plt.contourf(xx, yy, zz, cmap='Paired')

    # tworzenie wykresu punktowego dla klas ze zbioru X
    for class_value in range(3):

        # przyporządkowanie klasy (y) do obsewacji (X)
        row_ix = where(y_plot == class_value)

        # stworzenie wykresu punktowego
        plt.scatter(X_plot[row_ix, 0], X_plot[row_ix, 1], cmap='Paired', alpha=0.3, label=class_value)

    # wizualizacja wykresu
    plt.legend(loc='upper right')
    plt.show()

# %%
from sklearn.metrics import classification_report, f1_score, roc_auc_score, roc_curve, confusion_matrix, auc
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

metrics_dataframe = pd.DataFrame(columns = ['Model', 'F1_score', 'AUC'])
metrics_dataframe
models = []
models_names = []
predictions_proba_list = []

def calculate_metrics(model, name, X_checked, y_checked):
    models.append(model)
    models_names.append(name)
    global metrics_dataframe
    predictions = model.predict(X_checked)
    predictions_proba = model.predict_proba(X_checked)
    predictions_proba_list.append(predictions_proba)

    ############## metryki dla sprawdzanego modelu ################
    # Precision, Recall, F1, Accuracy
    print(classification_report(y_checked, predictions))

    # Confusion matrix
    plt.figure()
    cm = confusion_matrix(y_checked, predictions)
    ax = sns.heatmap(cm, annot=True, cmap='Blues', fmt='.0f')
    ax.set_title('Confusion Matrix\n\n')
    ax.set_xlabel('\nPredicted Values')
    ax.set_ylabel('Actual Values ')
    plt.show()

   # Plot ROC curve
    fig = plt.figure(figsize=(6, 6))
    plt.plot([0, 1], [0, 1], 'k--')

    # Liczymy ROC dla każdej klasy (one-vs-rest)
    for model_selected, name_selected, pred_proba in zip(models, models_names, predictions_proba_list):
        for i in range(3):  # Dla 3 klas
            fpr, tpr, thresholds = roc_curve(y_checked, pred_proba[:, i], pos_label=i)
            roc_auc = auc(fpr, tpr)
            plt.plot(fpr, tpr, label=f'{name_selected} Class {i} (AUC = {roc_auc:.2f})')

    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.show()

    # F1 Score (średnia z trzech klas)
    f1_metric = f1_score(y_checked, predictions, average='macro')  # Można zmienić na 'weighted' jeśli chcesz ważyć klasy

    # Obliczamy AUC
    auc_metric = roc_auc_score(y_checked, predictions_proba, multi_class='ovr', average='macro')

    # Dodanie metryk do dataframe
    new_row = pd.DataFrame({'Model': [name], 'F1_score': [f1_metric], 'AUC': [auc_metric]})
    metrics_dataframe = pd.concat([metrics_dataframe, new_row], ignore_index=True)
    return metrics_dataframe

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

scaler_2var = StandardScaler()
X_train_standardized = scaler_2var.fit_transform(X_train)
X_test_standardized = scaler_2var.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

model_knn = KNeighborsClassifier(n_neighbors= 1)
model_knn.fit(X_train_standardized, y_train)
plot_classification_surface(X_plot=X_train_standardized, y_plot=y_train, trained_model=model_knn)
# Out:
# C:\Users\Kasia\AppData\Local\Temp\ipykernel_10856\3124446580.py:43: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X_plot[row_ix, 0], X_plot[row_ix, 1], cmap='Paired', alpha=0.3, label=class_value)

# %%
calculate_metrics(model_knn, 'KNN', X_test_standardized, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        45
#            1       1.00      0.92      0.96        37
#            2       0.79      0.90      0.84        21
#
#     accuracy                           0.93       103
#    macro avg       0.92      0.93      0.92       103
# weighted avg       0.94      0.93      0.93       103
# C:\Users\Kasia\AppData\Local\Temp\ipykernel_10856\744908005.py:58: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   metrics_dataframe = pd.concat([metrics_dataframe, new_row], ignore_index=True)
#   Model  F1_score       AUC
# 0   KNN  0.919249  0.947296

# %%
from sklearn.tree import DecisionTreeClassifier

model_tree = DecisionTreeClassifier(max_depth=3, min_samples_leaf=2)
model_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_leaf=2)

# %%
import numpy as np
plot_classification_surface(X_plot=np.array(X_train), y_plot=y_train, trained_model=model_tree)
# Out:
# C:\Users\Kasia\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Kasia\AppData\Local\Temp\ipykernel_10856\3124446580.py:43: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X_plot[row_ix, 0], X_plot[row_ix, 1], cmap='Paired', alpha=0.3, label=class_value)

# %%
calculate_metrics(model_tree, 'Tree', X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96        45
#            1       1.00      0.95      0.97        37
#            2       0.86      0.86      0.86        21
#
#     accuracy                           0.94       103
#    macro avg       0.93      0.93      0.93       103
# weighted avg       0.94      0.94      0.94       103
#   Model  F1_score       AUC
# 0   KNN  0.919249  0.947296
# 1  Tree  0.928629  0.971078

# %%
from sklearn.svm import SVC

model_svm = SVC(kernel='rbf', probability=True)
model_svm.fit(X_train_standardized, y_train)
plot_classification_surface(X_plot=X_train_standardized, y_plot=y_train, trained_model=model_svm)
# Out:
# C:\Users\Kasia\AppData\Local\Temp\ipykernel_10856\3124446580.py:43: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X_plot[row_ix, 0], X_plot[row_ix, 1], cmap='Paired', alpha=0.3, label=class_value)

# %%
calculate_metrics(model_svm, 'SVM', X_test_standardized, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96        45
#            1       1.00      1.00      1.00        37
#            2       0.95      0.86      0.90        21
#
#     accuracy                           0.96       103
#    macro avg       0.96      0.94      0.95       103
# weighted avg       0.96      0.96      0.96       103
#   Model  F1_score       AUC
# 0   KNN  0.919249  0.947296
# 1  Tree  0.928629  0.971078
# 2   SVM  0.952174  0.991762

# %%
from sklearn.ensemble import RandomForestClassifier

model_forest = RandomForestClassifier(n_estimators=1000, max_depth=3, min_samples_leaf=5)
model_forest.fit(X_train, y_train)
plot_classification_surface(X_plot=np.array(X_train), y_plot=y_train, trained_model=model_forest)
# Out:
# C:\Users\Kasia\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Kasia\AppData\Local\Temp\ipykernel_10856\3124446580.py:43: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X_plot[row_ix, 0], X_plot[row_ix, 1], cmap='Paired', alpha=0.3, label=class_value)

# %%
calculate_metrics(model_forest, 'Random Forest', X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97        45
#            1       1.00      0.97      0.99        37
#            2       0.90      0.90      0.90        21
#
#     accuracy                           0.96       103
#    macro avg       0.95      0.95      0.95       103
# weighted avg       0.96      0.96      0.96       103
#            Model  F1_score       AUC
# 0            KNN  0.919249  0.947296
# 1           Tree  0.928629  0.971078
# 2            SVM  0.952174  0.991762
# 3  Random Forest  0.952699  0.987186

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

model_adaboost = AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=1), n_estimators=50)
model_adaboost.fit(X_train, y_train)

plot_classification_surface(X_plot=np.array(X_train), y_plot=y_train, trained_model=model_adaboost)
# Out:
# C:\Users\Kasia\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\Kasia\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but AdaBoostClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Kasia\AppData\Local\Temp\ipykernel_10856\3124446580.py:43: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X_plot[row_ix, 0], X_plot[row_ix, 1], cmap='Paired', alpha=0.3, label=class_value)

# %%
calculate_metrics(model_adaboost, 'model_adaboost', X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90        45
#            1       1.00      1.00      1.00        37
#            2       1.00      0.52      0.69        21
#
#     accuracy                           0.90       103
#    macro avg       0.94      0.84      0.86       103
# weighted avg       0.92      0.90      0.89       103
#             Model  F1_score       AUC
# 0             KNN  0.919249  0.947296
# 1            Tree  0.928629  0.971078
# 2             SVM  0.952174  0.991762
# 3   Random Forest  0.952699  0.987186
# 4  model_adaboost  0.862500  0.945438

# %%
from sklearn.ensemble import VotingClassifier

model_voting = VotingClassifier(estimators=[('Tree', model_tree),
                                            ('Random Forest', model_forest),
                                            ('AdaBoost', model_adaboost)],
                                voting='soft')

model_voting.fit(X_train, y_train)
plot_classification_surface(X_plot=np.array(X_train), y_plot=y_train, trained_model=model_voting)
# Out:
# C:\Users\Kasia\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# C:\Users\Kasia\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Kasia\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Kasia\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but AdaBoostClassifier was fitted with feature names
#   warnings.warn(
# ...

# %%
calculate_metrics(model_voting, 'VotingClassifier', X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96        45
#            1       1.00      0.95      0.97        37
#            2       0.86      0.86      0.86        21
#
#     accuracy                           0.94       103
#    macro avg       0.93      0.93      0.93       103
# weighted avg       0.94      0.94      0.94       103
#               Model  F1_score       AUC
# 0               KNN  0.919249  0.947296
# 1              Tree  0.928629  0.971078
# 2               SVM  0.952174  0.991762
# 3     Random Forest  0.952699  0.987186
# 4    model_adaboost  0.862500  0.945438
# 5  VotingClassifier  0.928629  0.991239

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0, stratify=y)

# %%
from sklearn.model_selection import GridSearchCV

random_forest = RandomForestClassifier(n_estimators=1000, n_jobs=-1)
params_rf = {'max_depth': [3, 5, 10, 20],
             'min_samples_leaf': [3, 5, 10, 15]}
rf_gridsearch = GridSearchCV(random_forest,
                             params_rf,
                             scoring='f1_macro',
                             cv=5,
                             verbose=10, n_jobs=-1)
rf_gridsearch.fit(X_train, y_train)
print('\nBest hyperparameter:', rf_gridsearch.best_params_)
rf_model_v2 = rf_gridsearch.best_estimator_
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
#
# Best hyperparameter: {'max_depth': 5, 'min_samples_leaf': 3}

# %%
calculate_metrics(rf_model_v2, 'rf_model_v2', X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97        45
#            1       1.00      1.00      1.00        37
#            2       0.95      0.90      0.93        21
#
#     accuracy                           0.97       103
#    macro avg       0.97      0.96      0.96       103
# weighted avg       0.97      0.97      0.97       103
#               Model  F1_score       AUC
# 0               KNN  0.919249  0.947296
# 1              Tree  0.928629  0.971078
# 2               SVM  0.952174  0.991762
# 3     Random Forest  0.952699  0.987186
# 4    model_adaboost  0.862500  0.945438
# 5  VotingClassifier  0.928629  0.991239
# 6       rf_model_v2  0.964621  0.996017

# %%
from sklearn.preprocessing import StandardScaler

scaler_2var = StandardScaler()
X_train_standardized = scaler_2var.fit_transform(X_train)
X_test_standardized = scaler_2var.transform(X_test)

# %%
model_knn = KNeighborsClassifier()
params_knn = {
   'n_neighbors': [3, 5, 10, 20, 50],  # Liczba najbliższych sąsiadów
    'weights': ['uniform', 'distance'],  # Typ wag
    'p': [1, 2]  # Metryka: Manhattan (p=1) lub Euclidean (p=2)
}
knn_gridsearch = GridSearchCV(
    model_knn,
    params_knn,
    scoring='f1_macro',  # Metryka optymalizacyjna
    cv=5,  # Walidacja krzyżowa
    verbose=10,
    n_jobs=-1)

knn_gridsearch.fit(X_train_standardized, y_train)

print('\nBest hyperparameters:', knn_gridsearch.best_params_)
knn_model_v1 = knn_gridsearch.best_estimator_
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
#
# Best hyperparameters: {'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}

# %%
calculate_metrics(knn_model_v1, 'knn_model_v1', X_test_standardized, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        45
#            1       1.00      1.00      1.00        37
#            2       0.95      0.95      0.95        21
#
#     accuracy                           0.98       103
#    macro avg       0.98      0.98      0.98       103
# weighted avg       0.98      0.98      0.98       103
#               Model  F1_score       AUC
# 0               KNN  0.919249  0.947296
# 1              Tree  0.928629  0.971078
# 2               SVM  0.952174  0.991762
# 3     Random Forest  0.952699  0.987186
# 4    model_adaboost  0.862500  0.945438
# 5  VotingClassifier  0.928629  0.991239
# 6       rf_model_v2  0.964621  0.996017
# 7      knn_model_v1  0.976720  0.999036

# %%
from sklearn.metrics import f1_score

y_train_pred = knn_model_v1.predict(X_train_standardized)  # Predykcje na zbiorze treningowym
y_test_pred = knn_model_v1.predict(X_test_standardized) # Predykcje na zbiorze test

# F1 score z użyciem metody 'macro'
f1_train = f1_score(y_train, y_train_pred, average='macro')  # F1 score na zbiorze treningowym
f1_test = f1_score(y_test, y_test_pred, average='macro')  # F1 score na zbiorze test

print(f"F1 score na zbiorze treningowym: {f1_train:.4f}")
print(f"F1 score na zbiorze testowym: {f1_test:.4f}")
# Out:
# F1 score na zbiorze treningowym: 1.0000
# F1 score na zbiorze testowym: 0.9767

# %%
from sklearn.metrics import f1_score

y_train_pred = rf_model_v2.predict(X_train)  # Predykcje na zbiorze treningowym
y_test_pred = rf_model_v2.predict(X_test) # Predykcje na zbiorze test

# F1 score z użyciem metody 'macro'
f1_train = f1_score(y_train, y_train_pred, average='macro')  # F1 score na zbiorze treningowym
f1_test = f1_score(y_test, y_test_pred, average='macro')  # F1 score na zbiorze test

print(f"F1 score na zbiorze treningowym: {f1_train:.4f}")
print(f"F1 score na zbiorze testowym: {f1_test:.4f}")
# Out:
# F1 score na zbiorze treningowym: 0.9949
# F1 score na zbiorze testowym: 0.9646
